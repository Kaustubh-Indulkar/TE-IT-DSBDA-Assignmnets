# %%
import pandas as pd

# %%
df=pd.read_csv('heart (1).csv')

# %%
df
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %%
df=df.drop_duplicates()

# %%
df
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %%
#DUPLICATES REMOVED

df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      0
# dtype: int64

# %%
#PLOT

import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trtbps', 'chol', 'fbs', 'restecg', 'thalachh',
#        'exng', 'oldpeak', 'slp', 'caa', 'thall', 'output'],
#       dtype='object')

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(),cmap='YlGnBu',annot=True)
# Out:
# <Axes: >

# %%
#LINE PLOT

sns.lineplot(df,x='age',y='cp',hue='output')
# Out:
# <Axes: xlabel='age', ylabel='cp'>

# %%
sns.lineplot(df,x='age',y='trtbps',hue='output')
# Out:
# <Axes: xlabel='age', ylabel='trtbps'>

# %%
sns.lineplot(df,x='age',y='chol',hue='output')
# Out:
# <Axes: xlabel='age', ylabel='chol'>

# %%
sns.lineplot(df,x='oldpeak',y='exng',hue='output')
# Out:
# <Axes: xlabel='oldpeak', ylabel='exng'>

# %%
# Shows the Distribution of Heat Diseases with respect to male and female
sns.histplot(df,x='output',hue='sex')
# Out:
# <Axes: xlabel='output', ylabel='Count'>

# %%
sns.histplot(df,x='cp',hue='sex')
# Out:
# <Axes: xlabel='cp', ylabel='Count'>

# %%
sns.histplot(df,x='cp',hue='output')
# Out:
# <Axes: xlabel='cp', ylabel='Count'>

# %%
# Shows the Distribution of age w.r.t output
sns.histplot(df,x='age',hue='output')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(df,x='trtbps',hue='output')
# Out:
# <Axes: xlabel='trtbps', ylabel='Count'>

# %%
temp_df=df[['age','cp', 'trtbps','chol','fbs','oldpeak','output']]
plt.figure(figsize=(15,10))
sns.pairplot(temp_df,hue='output')
plt.title("Looking for Insites in Data")
plt.legend("HeartDisease")
plt.tight_layout()
plt.plot()
# Out:
# F:\Anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_10836\121906232.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# []

# %%
plt.figure(figsize=(15,10))
for i, col in enumerate(temp_df.columns,1):
    plt.subplot(4,3,i)
    plt.title(f"Distribution of {col} Data")
    sns.histplot(df[col],kde=True)
    plt.tight_layout()
    plt.plot()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_10836\980562594.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_10836\980562594.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_10836\980562594.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_10836\980562594.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_10836\980562594.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_10836\980562594.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %%
sns.lineplot(df,x='age',y='thall',hue='restecg')
# Out:
# <Axes: xlabel='age', ylabel='thall'>
